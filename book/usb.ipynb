# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import requests
import tensorflow as tf
import time
from datetime import datetime
from tensorflow import keras
from tensorflow.keras import layers

# %%
def fetchData():
    res = requests.post("http://localhost:7001/api/etl/usb")
    result = res.json()
    return result

# %%
df = fetchData()
df = pd.json_normalize(df)
df
# Out:
#           date  monthLevel  week  month  isHoliday  isHolidayStart  isWeekend  \
# 0   2021-09-22         0.8     3      9          0               0          0
# 1   2021-09-23         0.8     4      9          0               0          0
# 2   2021-09-24         0.8     5      9          0               0          0
# 3   2021-09-25         0.8     6      9          0               0          1
# 4   2021-09-26         0.8     0      9          0               0          0
# 5   2021-09-27         0.8     1      9          0               0          0
# 6   2021-09-28         0.8     2      9          0               0          0
# 7   2021-09-29         0.8     3      9          0               0          0
# 8   2021-09-30         0.8     4      9          0               0          0
# 9   2021-10-01         0.8     5     10          1               1          0
# 10  2021-10-02         0.8     6     10          1               0          1
# 11  2021-10-03         0.8     0     10          1               0          1
# 12  2021-10-04         0.8     1     10          1               0          0
# 13  2021-10-05         0.8     2     10          1               0          0
# 14  2021-10-06         0.8     3     10          1               0          0
# 15  2021-10-07         0.8     4     10          1               0          0
# 16  2021-10-08         0.8     5     10          0               0          0
# 17  2021-10-09         0.8     6     10          0               0          0
# 18  2021-10-10         0.8     0     10          0               0          1
# 19  2021-10-11         0.8     1     10          0               0          0
# 20  2021-10-12         0.8     2     10          0               0          0
# 21  2021-10-13         0.8     3     10          0               0          0
# 22  2021-10-14         0.8     4     10          0               0          0
# 23  2021-10-15         0.8     5     10          0               0          0
# 24  2021-10-16         0.8     6     10          0               0          1
# 25  2021-10-17         0.8     0     10          0               0          1
#
#     isSaturday  isSunday  isMon  ...  60f976da05482c2ea6737a9c  \
# 0            0         0      0  ...                  0.237333
# 1            0         0      0  ...                  0.185333
# 2            0         0      0  ...                  0.156000
# 3            1         0      0  ...                  0.301333
# 4            0         1      0  ...                  0.210000
# 5            0         0      1  ...                  0.192000
# 6            0         0      0  ...                  0.147333
# 7            0         0      0  ...                  0.184667
# 8            0         0      0  ...                  0.266000
# 9            0         0      0  ...                  0.346667
# 10           1         0      0  ...                  0.348667
# 11           0         1      0  ...                  0.376000
# 12           0         0      1  ...                  0.360667
# 13           0         0      0  ...                  0.361333
# 14           0         0      0  ...                  0.371333
# 15           0         0      0  ...                  0.384000
# 16           0         0      0  ...                  0.388000
# 17           1         0      0  ...                  0.368667
# 18           0         1      0  ...                  0.258667
# 19           0         0      1  ...                  0.229333
# 20           0         0      0  ...                  0.220667
# 21           0         0      0  ...                  0.209333
# 22           0         0      0  ...                  0.222667
# 23           0         0      0  ...                  0.179333
# 24           1         0      0  ...                  0.347333
# 25           0         1      0  ...                  0.250667
#
#     5f8812ec14ae8a2d80450794  5fa23cdcbbdbd416ae43dc05  \
# 0                   0.208667                  0.150000
# 1                   0.161333                  0.076667
# 2                   0.179333                  0.040000
# 3                   0.325333                  0.192667
# 4                   0.213333                  0.085333
# 5                   0.172667                  0.084667
# 6                   0.089333                  0.053333
# 7                   0.109333                  0.078667
# 8                   0.260667                  0.127333
# 9                   0.365333                  0.218000
# 10                  0.342667                  0.183333
# 11                  0.340667                  0.219333
# 12                  0.306667                  0.222667
# 13                  0.581333                  0.182667
# 14                  0.488000                  0.257333
# 15                  0.686000                  0.238667
# 16                  0.753333                  0.278000
# 17                  0.602000                  0.238667
# 18                  0.460000                  0.142000
# 19                  0.461333                  0.136667
# 20                  0.389333                  0.128667
# 21                  0.380667                  0.098000
# 22                  0.426000                  0.108000
# 23                  0.316000                  0.050000
# 24                  0.583333                  0.229333
# 25                  0.435333                  0.144667
#
#     611e57d62f02d506f768dec8  5f914afc26509774c642cf42  \
# 0                   0.118000                  0.078000
# 1                   0.145333                  0.048000
# 2                   0.104667                  0.065333
# 3                   0.144000                  0.242000
# 4                   0.113333                  0.070000
# 5                   0.092000                  0.058000
# 6                   0.132667                  0.040000
# 7                   0.133333                  0.040000
# 8                   0.127333                  0.157333
# 9                   0.178667                  0.282667
# 10                  0.140000                  0.232667
# 11                  0.216000                  0.296000
# 12                  0.196000                  0.260667
# 13                  0.195333                  0.240000
# 14                  0.269333                  0.301333
# 15                  0.314667                  0.307333
# 16                  0.302000                  0.344667
# 17                  0.318667                  0.333333
# 18                  0.167333                  0.112000
# 19                  0.195333                  0.158000
# 20                  0.288000                  0.127333
# 21                  0.275333                  0.124000
# 22                  0.261333                  0.152667
# 23                  0.193333                  0.088000
# 24                  0.304000                  0.382667
# 25                  0.306667                  0.158667
#
#     60f97dfceb33e120fe66fc3e  5f9161f64b89d447253b02c5  \
# 0                   0.063333                  0.058667
# 1                   0.050667                  0.044000
# 2                   0.024000                  0.023333
# 3                   0.093333                  0.078667
# 4                   0.042667                  0.040000
# 5                   0.049333                  0.052000
# 6                   0.042000                  0.055333
# 7                   0.050667                  0.044667
# 8                   0.070667                  0.053333
# 9                   0.118000                  0.110667
# 10                  0.092667                  0.097333
# 11                  0.130667                  0.097333
# 12                  0.117333                  0.086667
# 13                  0.098667                  0.076000
# 14                  0.141333                  0.104667
# 15                  0.143333                  0.141333
# 16                  0.162000                  0.127333
# 17                  0.143333                  0.102000
# 18                  0.074667                  0.062000
# 19                  0.073333                  0.063333
# 20                  0.065333                  0.061333
# 21                  0.066000                  0.056000
# 22                  0.072000                  0.056000
# 23                  0.042667                  0.040667
# 24                  0.134667                  0.130000
# 25                  0.073333                  0.053333
#
#     611f0913e291ec2b16214a88  5f91526a68ff66780876eaaf  \
# 0                   0.040000                  0.040000
# 1                   0.040000                  0.026667
# 2                   0.023333                       NaN
# 3                   0.040000                       NaN
# 4                   0.040000                       NaN
# 5                   0.040000                       NaN
# 6                   0.040000                       NaN
# 7                   0.040000                       NaN
# 8                   0.040000                       NaN
# 9                   0.046667                       NaN
# 10                  0.046667                       NaN
# 11                  0.046667                       NaN
# 12                  0.047333                       NaN
# 13                  0.046667                       NaN
# 14                  0.046667                       NaN
# 15                  0.052667                       NaN
# 16                  0.047333                       NaN
# 17                  0.052000                       NaN
# 18                  0.040000                       NaN
# 19                  0.040000                       NaN
# 20                  0.040000                       NaN
# 21                  0.040000                       NaN
# 22                  0.040000                       NaN
# 23                  0.040000                       NaN
# 24                  0.042000                       NaN
# 25                  0.040000                       NaN
#
#     5fa24b84b9227045895c7495
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                  0.658667
# 11                  0.738000
# 12                  0.554667
# 13                  0.705333
# 14                  0.782667
# 15                  0.720667
# 16                  0.888667
# 17                  0.832667
# 18                  0.645333
# 19                  0.623333
# 20                  0.548667
# 21                  0.503333
# 22                  0.646667
# 23                  0.448000
# 24                  0.838000
# 25                  0.659333
#
# [26 rows x 35 columns]

# %%
# 
# df['flows'] = df['max']
# df['tickets'] = df['total']
dataset = df[['attsMark', 'isMon', 'isFri', 'isSaturday', 'isSunday', 'isHoliday', 'weaLevel', 'price', 'monthLevel']]
dataset = dataset[1:]
dataset
# Out:
#     attsMark  isMon  isFri  isSaturday  isSunday  isHoliday  weaLevel  \
# 1     0.4401      0      0           0         0          0      0.80
# 2     0.3264      0      1           0         0          0      0.55
# 3     0.7430      0      0           1         0          0      0.65
# 4     0.4441      0      0           0         1          0      0.60
# 5     0.4151      1      0           0         0          0      0.75
# 6     0.2873      0      0           0         0          0      1.00
# 7     0.3203      0      0           0         0          0      0.65
# 8     0.5361      0      0           0         0          0      1.00
# 9     0.8679      0      1           0         0          1      0.80
# 10    0.9031      0      0           1         0          1      0.80
# 11    1.0000      0      0           0         1          1      0.55
# 12    0.9632      1      0           0         0          1      0.60
# 13    0.9508      0      0           0         0          1      0.80
# 14    1.0000      0      0           0         0          1      0.75
# 15    1.0000      0      0           0         0          1      1.00
# 16    1.0000      0      1           0         0          0      0.70
# 17    1.0000      0      0           1         0          0      0.80
# 18    0.7055      0      0           0         1          0      1.00
# 19    0.7175      1      0           0         0          0      1.00
# 20    0.6424      0      0           0         0          0      1.00
# 21    0.5800      0      0           0         0          0      0.80
# 22    0.6777      0      0           0         0          0      1.00
# 23    0.4585      0      1           0         0          0      1.00
# 24    1.0000      0      0           1         0          0      1.00
# 25    0.7334      0      0           0         1          0      1.00
#
#        price  monthLevel
# 1   0.852941         0.8
# 2   0.852941         0.8
# 3   0.852941         0.8
# 4   0.852941         0.8
# 5   0.852941         0.8
# 6   0.852941         0.8
# 7   0.852941         0.8
# 8   0.852941         0.8
# 9   0.852941         0.8
# 10  1.000000         0.8
# 11  1.000000         0.8
# 12  1.000000         0.8
# 13  1.000000         0.8
# 14  1.000000         0.8
# 15  0.852941         0.8
# 16  0.705882         0.8
# 17  0.705882         0.8
# 18  0.852941         0.8
# 19  0.705882         0.8
# 20  0.705882         0.8
# 21  0.705882         0.8
# 22  0.705882         0.8
# 23  0.852941         0.8
# 24  0.852941         0.8
# 25  0.852941         0.8

# %%
# 拆分训练数据集和测试数据集
train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)
dataset.drop(train_dataset.index)
# Out:
#     attsMark  isMon  isFri  isSaturday  isSunday  isHoliday  weaLevel  \
# 1     0.4401      0      0           0         0          0       0.8
# 4     0.4441      0      0           0         1          0       0.6
# 13    0.9508      0      0           0         0          1       0.8
# 16    1.0000      0      1           0         0          0       0.7
# 22    0.6777      0      0           0         0          0       1.0
#
#        price  monthLevel
# 1   0.852941         0.8
# 4   0.852941         0.8
# 13  1.000000         0.8
# 16  0.705882         0.8
# 22  0.705882         0.8

# %%
train_stats = train_dataset.describe()
train_stats.pop("attsMark")
train_stats = train_stats.transpose()

train_stats
# Out:
#             count      mean           std       min       25%       50%  \
# isMon        20.0  0.150000  3.663475e-01  0.000000  0.000000  0.000000
# isFri        20.0  0.150000  3.663475e-01  0.000000  0.000000  0.000000
# isSaturday   20.0  0.200000  4.103913e-01  0.000000  0.000000  0.000000
# isSunday     20.0  0.150000  3.663475e-01  0.000000  0.000000  0.000000
# isHoliday    20.0  0.300000  4.701623e-01  0.000000  0.000000  0.000000
# weaLevel     20.0  0.835000  1.702166e-01  0.550000  0.725000  0.800000
# price        20.0  0.852941  9.542437e-02  0.705882  0.852941  0.852941
# monthLevel   20.0  0.800000  1.139065e-16  0.800000  0.800000  0.800000
#
#                  75%  max
# isMon       0.000000  1.0
# isFri       0.000000  1.0
# isSaturday  0.000000  1.0
# isSunday    0.000000  1.0
# isHoliday   1.000000  1.0
# weaLevel    1.000000  1.0
# price       0.852941  1.0
# monthLevel  0.800000  0.8

# %%
# 从标签中分离特征
train_labels = train_dataset.pop('attsMark')
test_labels = test_dataset.pop('attsMark')

normed_train_data = train_dataset
normed_test_data = test_dataset

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()
model.summary()

example_batch = normed_train_data[:3]
example_result = model.predict(example_batch)
example_result
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                576
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,801
# Trainable params: 4,801
# Non-trainable params: 0
# _________________________________________________________________
# array([[ 0.20817465],
#        [-0.03287928],
#        [ 0.19265357]], dtype=float32)

# %%
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 495  0.001997  0.035835  0.001997  0.054749  0.213337  0.054749    495
# 496  0.002049  0.039137  0.002049  0.061132  0.209173  0.061132    496
# 497  0.002177  0.037430  0.002177  0.054406  0.212778  0.054406    497
# 498  0.002207  0.041378  0.002207  0.061281  0.209041  0.061281    498
# 499  0.002238  0.038113  0.002238  0.055037  0.213743  0.055037    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [Total]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,1])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$Total^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,1])
  plt.legend()
  plt.show()


plot_history(history)

# %%
model = build_model()

# patience 值用来检查改进 epochs 的数量
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(normed_train_data, train_labels, epochs=EPOCHS, validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# .............

# %%
# 做预测
test_predictions = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Total]')
plt.ylabel('Predictions [Total]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100000, 100000], [-100000, 100000])

# %%
model.save('../model/usb_flows.h5')

normed_test_data
# Out:
#     isMon  isFri  isSaturday  isSunday  isHoliday  weaLevel     price  \
# 1       0      0           0         0          0       0.8  0.852941
# 4       0      0           0         1          0       0.6  0.852941
# 13      0      0           0         0          1       0.8  1.000000
# 16      0      1           0         0          0       0.7  0.705882
# 22      0      0           0         0          0       1.0  0.705882
#
#     monthLevel
# 1          0.8
# 4          0.8
# 13         0.8
# 16         0.8
# 22         0.8
