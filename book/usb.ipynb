# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import requests
import tensorflow as tf
import time
import json
from datetime import datetime
from tensorflow import keras
from tensorflow.keras import layers

# %%
def fetchData(startDate, endDate):
    res = requests.post("http://localhost:7001/api/etl/usb", data={'startDate': startDate, 'endDate': endDate})
    res = res.json()
    return res

# %%
df = fetchData('2022-02-01', '2022-02-14')
df = pd.json_normalize(df)
df
# Out:
#           date  monthLevel  week  month  isHoliday  isHolidayStart  isWeekend  \
# 0   2022-02-01         0.4     2      2          1               0          0
# 1   2022-02-02         0.4     3      2          1               0          0
# 2   2022-02-03         0.4     4      2          1               0          0
# 3   2022-02-04         0.4     5      2          1               0          0
# 4   2022-02-05         0.4     6      2          1               0          1
# 5   2022-02-06         0.4     0      2          1               0          1
# 6   2022-02-07         0.4     1      2          0               0          0
# 7   2022-02-08         0.4     2      2          0               0          0
# 8   2022-02-09         0.4     3      2          0               0          0
# 9   2022-02-10         0.4     4      2          0               0          0
# 10  2022-02-11         0.4     5      2          0               0          0
# ...

# %%
# 
# df['flows'] = df['max']
# df['tickets'] = df['total']
dataset = df[['attsMark', 'isMon', 'isFri', 'isSaturday', 'isSunday', 'isHoliday', 'weaLevel', 'price', 'year_YX', 'year_ZX']]
dataset = dataset[1:]
dataset
# Out:
#     attsMark  isMon  isFri  isSaturday  isSunday  isHoliday  weaLevel  \
# 1     0.4762      0      0           0         0          1       1.0
# 2     0.4360      0      0           0         0          1       1.0
# 3     0.3390      0      1           0         0          1       1.0
# 4     0.2739      0      0           1         0          1       1.0
# 5     0.4390      0      0           0         1          1       1.0
# 6     0.7016      1      0           0         0          0       1.0
# 7     0.7006      0      0           0         0          0       1.0
# 8     0.6692      0      0           0         0          0       1.0
# 9     0.7757      0      0           0         0          0       1.0
# 10    0.6473      0      1           0         0          0       0.9
# 11    0.4321      0      0           1         0          0       0.8
# 12    0.3264      0      0           0         1          0       0.4
# ...

# %%
# 拆分训练数据集和测试数据集
train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)
dataset.drop(train_dataset.index)
# Out:
#     attsMark  isMon  isFri  isSaturday  isSunday  isHoliday  weaLevel  \
# 1     0.4762      0      0           0         0          1       1.0
# 6     0.7016      1      0           0         0          0       1.0
# 13    0.9586      1      0           0         0          0       1.0
#
#        price  year_YX  year_ZX
# 1   1.000000        0        0
# 6   0.705882        1        1
# 13  0.558824        1        1

# %%
# 训练集
train_stats = train_dataset.describe()
train_stats.pop("attsMark")
train_stats = train_stats.transpose()

train_stats
# Out:
#             count      mean       std       min       25%       50%       75%  \
# isMon        10.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# isFri        10.0  0.200000  0.421637  0.000000  0.000000  0.000000  0.000000
# isSaturday   10.0  0.200000  0.421637  0.000000  0.000000  0.000000  0.000000
# isSunday     10.0  0.200000  0.421637  0.000000  0.000000  0.000000  0.000000
# isHoliday    10.0  0.400000  0.516398  0.000000  0.000000  0.000000  1.000000
# weaLevel     10.0  0.910000  0.191195  0.400000  0.925000  1.000000  1.000000
# price        10.0  0.808824  0.139512  0.705882  0.705882  0.705882  0.963235
# year_YX      10.0  0.400000  0.516398  0.000000  0.000000  0.000000  1.000000
# year_ZX      10.0  0.600000  0.516398  0.000000  0.000000  1.000000  1.000000
#
#             max
# isMon       0.0
# isFri       1.0
# isSaturday  1.0
# isSunday    1.0
# isHoliday   1.0
# weaLevel    1.0
# price       1.0
# year_YX     1.0
# year_ZX     1.0

# %%
# 从标签中分离特征
train_labels = train_dataset.pop('attsMark')
test_labels = test_dataset.pop('attsMark')

normed_train_data = train_dataset
normed_test_data = test_dataset

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-06)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()
model.summary()

example_batch = normed_train_data[:1]
example_result = model.predict(example_batch)
example_result
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_93 (Dense)             (None, 64)                640
# _________________________________________________________________
# dense_94 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_95 (Dense)             (None, 1)                 65
# ...
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 495  0.001169  0.029563  0.001169  0.075437  0.248400  0.075437    495
# 496  0.001178  0.025962  0.001178  0.066480  0.245527  0.066480    496
# 497  0.001164  0.029463  0.001164  0.075473  0.248566  0.075473    497
# 498  0.001179  0.025977  0.001179  0.066382  0.245520  0.066382    498
# 499  0.001177  0.029720  0.001177  0.075556  0.248616  0.075556    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [Total]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,1])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$Total^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,1])
  plt.legend()
  plt.show()


plot_history(history)

# %%
model = build_model()

# patience 值用来检查改进 epochs 的数量
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(normed_train_data, train_labels, epochs=EPOCHS, validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# ........................................

# %%
# 做预测
test_predictions = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Total]')
plt.ylabel('Predictions [Total]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100000, 100000], [-100000, 100000])
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78290f68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
model.save('../model/usb_flows.h5')

normed_test_data
# Out:
#     isMon  isFri  isSaturday  isSunday  isHoliday  weaLevel     price  \
# 1       0      0           0         0          1       1.0  1.000000
# 6       1      0           0         0          0       1.0  0.705882
# 13      1      0           0         0          0       1.0  0.558824
#
#     year_YX  year_ZX
# 1         0        0
# 6         1        1
# 13        1        1
