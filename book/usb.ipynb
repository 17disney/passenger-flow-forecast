# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import requests
import tensorflow as tf
import time
from datetime import datetime
from tensorflow import keras
from tensorflow.keras import layers

# %%
def fetchData():
    res = requests.post("http://localhost:7001/api/etl/usb")
    result = res.json()
    return result

# %%
df = fetchData()
df = pd.json_normalize(df)
df
# Out:
#           date  monthLevel  week  month  isHoliday  isHolidayStart  isWeekend  \
# 0   2021-09-22         0.8     3      9          0               0          0
# 1   2021-09-23         0.8     4      9          0               0          0
# 2   2021-09-24         0.8     5      9          0               0          0
# 3   2021-09-25         0.8     6      9          0               0          1
# 4   2021-09-26         0.8     0      9          0               0          0
# 5   2021-09-27         0.8     1      9          0               0          0
# 6   2021-09-28         0.8     2      9          0               0          0
# 7   2021-09-29         0.8     3      9          0               0          0
# 8   2021-09-30         0.8     4      9          0               0          0
# 9   2021-10-01         0.8     5     10          1               1          0
# 10  2021-10-02         0.8     6     10          1               0          1
# 11  2021-10-03         0.8     0     10          1               0          1
# 12  2021-10-04         0.8     1     10          1               0          0
# 13  2021-10-05         0.8     2     10          1               0          0
# 14  2021-10-06         0.8     3     10          1               0          0
# 15  2021-10-07         0.8     4     10          1               0          0
# 16  2021-10-08         0.8     5     10          0               0          0
# 17  2021-10-09         0.8     6     10          0               0          0
# 18  2021-10-10         0.8     0     10          0               0          1
# 19  2021-10-11         0.8     1     10          0               0          0
# 20  2021-10-12         0.8     2     10          0               0          0
# 21  2021-10-13         0.8     3     10          0               0          0
# 22  2021-10-14         0.8     4     10          0               0          0
# 23  2021-10-15         0.8     5     10          0               0          0
# 24  2021-10-16         0.8     6     10          0               0          1
#
#     isSaturday  isSunday  isMon  isFri  attsMark  stock     price  tempAvg  \
# 0            0         0      0      0    0.5460  10000  0.852941     22.5
# 1            0         0      0      0    0.4401  10000  0.852941     21.5
# 2            0         0      0      1    0.3264  10000  0.852941     18.0
# 3            1         0      0      0    0.7430  10000  0.852941     20.5
# 4            0         1      0      0    0.4441  10000  0.852941     18.5
# 5            0         0      1      0    0.4151  10000  0.852941     21.5
# 6            0         0      0      0    0.2873  10000  0.852941     20.0
# 7            0         0      0      0    0.3203  10000  0.852941     21.5
# 8            0         0      0      0    0.5361  10000  0.852941     18.5
# 9            0         0      0      1    0.8679  10000  0.852941     19.0
# 10           1         0      0      0    0.9031  10000  1.000000     18.5
# 11           0         1      0      0    1.0000  10000  1.000000     17.5
# 12           0         0      1      0    0.9632  10000  1.000000     14.0
# 13           0         0      0      0    0.9508  10000  1.000000     13.5
# 14           0         0      0      0    1.0000  10000  1.000000      8.0
# 15           0         0      0      0    1.0000  10000  0.852941     12.5
# 16           0         0      0      1    1.0000  10000  0.705882     15.0
# 17           1         0      0      0    1.0000  10000  0.705882     12.0
# 18           0         1      0      0    0.7055  10000  0.852941     10.0
# 19           0         0      1      0    0.7175  10000  0.705882     11.5
# 20           0         0      0      0    0.6424  10000  0.705882     14.0
# 21           0         0      0      0    0.5800  10000  0.705882     15.5
# 22           0         0      0      0    0.6777  10000  0.705882     15.0
# 23           0         0      0      1    0.4585  10000  0.852941     11.0
# 24           1         0      0      0    0.0065   9995  0.852941      6.5
#
#     tempLevel  weaLevel
# 0       1.000      1.00
# 1       1.000      0.80
# 2       0.950      0.55
# 3       1.000      0.65
# 4       0.975      0.60
# 5       1.000      0.75
# 6       1.000      1.00
# 7       1.000      0.65
# 8       0.975      1.00
# 9       1.000      0.80
# 10      0.975      0.80
# 11      0.925      0.55
# 12      0.750      0.60
# 13      0.725      0.80
# 14      0.450      0.75
# 15      0.675      1.00
# 16      0.800      0.70
# 17      0.650      0.80
# 18      0.550      1.00
# 19      0.625      1.00
# 20      0.750      1.00
# 21      0.825      0.80
# 22      0.800      1.00
# 23      0.600      1.00
# 24      0.375      1.00

# %%
# 
# df['flows'] = df['max']
# df['tickets'] = df['total']
dataset = df[['attsMark', 'isMon', 'isFri', 'isSaturday', 'isSunday', 'isHoliday', 'isHolidayStart', 'weaLevel', 'price', 'monthLevel']]
dataset = dataset[1:]
dataset
# Out:
#     attsMark  isMon  isFri  isSaturday  isSunday  isHoliday  isHolidayStart  \
# 1     0.4401      0      0           0         0          0               0
# 2     0.3264      0      1           0         0          0               0
# 3     0.7430      0      0           1         0          0               0
# 4     0.4441      0      0           0         1          0               0
# 5     0.4151      1      0           0         0          0               0
# 6     0.2873      0      0           0         0          0               0
# 7     0.3203      0      0           0         0          0               0
# 8     0.5361      0      0           0         0          0               0
# 9     0.8679      0      1           0         0          1               1
# 10    0.9031      0      0           1         0          1               0
# 11    1.0000      0      0           0         1          1               0
# 12    0.9632      1      0           0         0          1               0
# 13    0.9508      0      0           0         0          1               0
# 14    1.0000      0      0           0         0          1               0
# 15    1.0000      0      0           0         0          1               0
# 16    1.0000      0      1           0         0          0               0
# 17    1.0000      0      0           1         0          0               0
# 18    0.7055      0      0           0         1          0               0
# 19    0.7175      1      0           0         0          0               0
# 20    0.6424      0      0           0         0          0               0
# 21    0.5800      0      0           0         0          0               0
# 22    0.6777      0      0           0         0          0               0
# 23    0.4585      0      1           0         0          0               0
# 24    0.0065      0      0           1         0          0               0
#
#     weaLevel     price  monthLevel
# 1       0.80  0.852941         0.8
# 2       0.55  0.852941         0.8
# 3       0.65  0.852941         0.8
# 4       0.60  0.852941         0.8
# 5       0.75  0.852941         0.8
# 6       1.00  0.852941         0.8
# 7       0.65  0.852941         0.8
# 8       1.00  0.852941         0.8
# 9       0.80  0.852941         0.8
# 10      0.80  1.000000         0.8
# 11      0.55  1.000000         0.8
# 12      0.60  1.000000         0.8
# 13      0.80  1.000000         0.8
# 14      0.75  1.000000         0.8
# 15      1.00  0.852941         0.8
# 16      0.70  0.705882         0.8
# 17      0.80  0.705882         0.8
# 18      1.00  0.852941         0.8
# 19      1.00  0.705882         0.8
# 20      1.00  0.705882         0.8
# 21      0.80  0.705882         0.8
# 22      1.00  0.705882         0.8
# 23      1.00  0.852941         0.8
# 24      1.00  0.852941         0.8

# %%
# 拆分训练数据集和测试数据集
train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)
dataset.drop(train_dataset.index)
# Out:
#     attsMark  isMon  isFri  isSaturday  isSunday  isHoliday  isHolidayStart  \
# 1     0.4401      0      0           0         0          0               0
# 4     0.4441      0      0           0         1          0               0
# 13    0.9508      0      0           0         0          1               0
# 16    1.0000      0      1           0         0          0               0
# 22    0.6777      0      0           0         0          0               0
#
#     weaLevel     price  monthLevel
# 1        0.8  0.852941         0.8
# 4        0.6  0.852941         0.8
# 13       0.8  1.000000         0.8
# 16       0.7  0.705882         0.8
# 22       1.0  0.705882         0.8

# %%
train_stats = train_dataset.describe()
train_stats.pop("attsMark")
train_stats = train_stats.transpose()

train_stats
# Out:
#                 count      mean           std       min       25%       50%  \
# isMon            19.0  0.157895  3.746343e-01  0.000000  0.000000  0.000000
# isFri            19.0  0.157895  3.746343e-01  0.000000  0.000000  0.000000
# isSaturday       19.0  0.210526  4.188539e-01  0.000000  0.000000  0.000000
# isSunday         19.0  0.105263  3.153018e-01  0.000000  0.000000  0.000000
# isHoliday        19.0  0.315789  4.775669e-01  0.000000  0.000000  0.000000
# isHolidayStart   19.0  0.052632  2.294157e-01  0.000000  0.000000  0.000000
# weaLevel         19.0  0.826316  1.702681e-01  0.550000  0.700000  0.800000
# price            19.0  0.852941  9.803922e-02  0.705882  0.852941  0.852941
# monthLevel       19.0  0.800000  1.140646e-16  0.800000  0.800000  0.800000
#
#                      75%  max
# isMon           0.000000  1.0
# isFri           0.000000  1.0
# isSaturday      0.000000  1.0
# isSunday        0.000000  1.0
# isHoliday       1.000000  1.0
# isHolidayStart  0.000000  1.0
# weaLevel        1.000000  1.0
# price           0.852941  1.0
# monthLevel      0.800000  0.8

# %%
# 从标签中分离特征
train_labels = train_dataset.pop('attsMark')
test_labels = test_dataset.pop('attsMark')

normed_train_data = train_dataset
normed_test_data = test_dataset

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()
model.summary()

example_batch = normed_train_data[:3]
example_result = model.predict(example_batch)
example_result
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_48 (Dense)             (None, 64)                640
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd6e896fb80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[ 0.0066468 ],
#        [ 0.09041962],
#        [-0.19110161]], dtype=float32)

# %%
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 495  0.003637  0.051912  0.003637  0.069619  0.261465  0.069619    495
# 496  0.004316  0.052239  0.004316  0.023114  0.144872  0.023114    496
# 497  0.003872  0.055235  0.003872  0.066705  0.255655  0.066705    497
# 498  0.003552  0.047293  0.003552  0.025955  0.154819  0.025955    498
# 499  0.002994  0.046720  0.002994  0.060703  0.243658  0.060703    499

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [Total]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,1])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$Total^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,1])
  plt.legend()
  plt.show()


plot_history(history)

# %%
model = build_model()

# patience 值用来检查改进 epochs 的数量
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(normed_train_data, train_labels, epochs=EPOCHS, validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# ...............................

# %%
# 做预测
test_predictions = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Total]')
plt.ylabel('Predictions [Total]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100000, 100000], [-100000, 100000])
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd6e8919c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
model.save('../model/usb_flows.h5')

normed_test_data
# Out:
#     isMon  isFri  isSaturday  isSunday  isHoliday  isHolidayStart  weaLevel  \
# 1       0      0           0         0          0               0       0.8
# 4       0      0           0         1          0               0       0.6
# 13      0      0           0         0          1               0       0.8
# 16      0      1           0         0          0               0       0.7
# 22      0      0           0         0          0               0       1.0
#
#        price  monthLevel
# 1   0.852941         0.8
# 4   0.852941         0.8
# 13  1.000000         0.8
# 16  0.705882         0.8
# 22  0.705882         0.8
